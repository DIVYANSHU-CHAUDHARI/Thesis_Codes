# %%
import scipy.io
import seaborn as sns
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('2hp_all_faults_1750.csv')

# %%
df = df[df['fault'] != '21_OR2']
df = df[df['fault'] != '21_OR3']
df = df[df['fault'] != '7_OR2']
df = df[df['fault'] != '7_OR3']

# %%
df['fault'].unique()
# Out:
# array(['21_BA', 'N', '21_IR', '21_OR1', '14_BA', '7_IR', '7_OR1', '14_IR',
#        '7_BA', '14_OR1'], dtype=object)

# %%
np.random.normal(0, 1, df.shape[0])
signal_energy = np.mean(df['DE_data']**2)
print(signal_energy)
white_noise_1 = np.clip(np.random.normal(0, 1, df.shape[0]), -1.2, 1.1) # -4.5
signal_energy = np.mean(df['DE_data']**2)
noise_energy = np.mean(white_noise_1**2)
SNR =  10*np.log10(signal_energy/noise_energy)
print(SNR)
# Out:
# 0.23307969559679226
# -4.153204768218101

# %%
df['DE_data'] = df['DE_data'] + white_noise_1

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

win_len=1200
stride=300

X=[]
Y=[]


for k in df['fault'].unique():
    
    df_temp_2 = df[df['fault']==k]
    
    for i in np.arange(0,len(df_temp_2)-(win_len),stride):
        temp = df_temp_2.iloc[i:i+win_len,:-1].values
        temp = temp.reshape((1,-1))
        X.append(temp)
        Y.append(df_temp_2.iloc[i+win_len,-1])
    
X=np.array(X)
print(X.shape)
X=X.reshape((X.shape[0],-1,1))
#X = np.repeat(X, 3, axis=3) # To repeat into 3 chanel format


Y=np.array(Y)
encoder= LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)
OHE_Y = to_categorical(encoded_Y)
# Out:
# (16205, 1, 1200)

# %%
X.shape
# Out:
# (16205, 1200, 1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,OHE_Y,test_size=0.2,shuffle=True)

# %%
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Input,Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D,Conv1D,MaxPooling1D
from tensorflow.keras.layers import LSTM
from keras.layers import BatchNormalization

# from tensorflow.keras.models import load_model
# cnn_model = load_model(r'H:\Gear Fault\Trained Model\CNN_model_gear.h5')



no_classes = len(df['fault'].unique())

cnn_model = Sequential()
cnn_model.add(Conv1D(filters=16, kernel_size=200, activation='relu', input_shape=(X.shape[1],X.shape[2])))
cnn_model.add(MaxPooling1D(pool_size=2))
cnn_model.add(BatchNormalization())
cnn_model.add(Conv1D(filters=32, kernel_size=100, activation='relu'))
cnn_model.add(MaxPooling1D(pool_size=2))
cnn_model.add(BatchNormalization())
cnn_model.add(Conv1D(filters=64, kernel_size=50, activation='relu'))
# cnn_model = Sequential()
# cnn_model.add(Conv1D(filters=64, kernel_size=100, activation='relu', input_shape=(X.shape[1],X.shape[2])))
# cnn_model.add(Conv1D(filters=32, kernel_size=50, activation='relu'))

# cnn_model.add(MaxPooling1D(pool_size=4))
# cnn_model.add(MaxPooling1D(pool_size=4))
cnn_model.add(Dropout(0.5))
cnn_model.add(LSTM(32))
# cnn_model.add(Flatten())
# cnn_model.add(Dense(40, activation='relu'))
cnn_model.add(Dense(no_classes, activation='softmax'))

cnn_model.summary()

cnn_model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 1001, 16)          3216
#
#  max_pooling1d (MaxPooling1D  (None, 500, 16)          0
#  )
#
#  batch_normalization (BatchN  (None, 500, 16)          64
#  ormalization)
#
#  conv1d_1 (Conv1D)           (None, 401, 32)           51232
#
#  max_pooling1d_1 (MaxPooling  (None, 200, 32)          0
#  1D)
#
#  batch_normalization_1 (Batc  (None, 200, 32)          128
#  hNormalization)
#
#  conv1d_2 (Conv1D)           (None, 151, 64)           102464
#
#  dropout (Dropout)           (None, 151, 64)           0
#
#  lstm (LSTM)                 (None, 32)                12416
#
#  dense (Dense)               (None, 10)                330
#
# =================================================================
# Total params: 169,850
# Trainable params: 169,754
# Non-trainable params: 96
# _________________________________________________________________

# %%
batch_size =300
epochs = 50
history = cnn_model.fit(X_train, y_train, batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(X_test,y_test),shuffle=True)
# Out:
# Epoch 1/50
# 2022-02-28 00:25:24.732662: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 44/44 [==============================] - 27s 591ms/step - loss: 0.4301 - accuracy: 0.1790 - val_loss: 0.3570 - val_accuracy: 0.1487
# Epoch 2/50
# 44/44 [==============================] - 27s 618ms/step - loss: 0.2959 - accuracy: 0.2958 - val_loss: 0.2918 - val_accuracy: 0.2940
# Epoch 3/50
# 44/44 [==============================] - 28s 642ms/step - loss: 0.2676 - accuracy: 0.3615 - val_loss: 0.2776 - val_accuracy: 0.2971
# Epoch 4/50
# 44/44 [==============================] - 28s 648ms/step - loss: 0.2454 - accuracy: 0.4424 - val_loss: 0.2613 - val_accuracy: 0.3807
# Epoch 5/50
# 44/44 [==============================] - 28s 644ms/step - loss: 0.2263 - accuracy: 0.4937 - val_loss: 0.2484 - val_accuracy: 0.4107
# Epoch 6/50
# 44/44 [==============================] - 29s 664ms/step - loss: 0.2065 - accuracy: 0.5461 - val_loss: 0.2541 - val_accuracy: 0.4338
# Epoch 7/50
# 44/44 [==============================] - 29s 654ms/step - loss: 0.1947 - accuracy: 0.5692 - val_loss: 0.2637 - val_accuracy: 0.4372
# Epoch 8/50
# 44/44 [==============================] - 29s 649ms/step - loss: 0.1834 - accuracy: 0.5950 - val_loss: 0.2473 - val_accuracy: 0.4443
# Epoch 9/50
# 44/44 [==============================] - 29s 653ms/step - loss: 0.1731 - accuracy: 0.6221 - val_loss: 0.2253 - val_accuracy: 0.4813
# Epoch 10/50
# 44/44 [==============================] - 29s 650ms/step - loss: 0.1646 - accuracy: 0.6479 - val_loss: 0.1890 - val_accuracy: 0.5646
# Epoch 11/50
# 44/44 [==============================] - 28s 648ms/step - loss: 0.1547 - accuracy: 0.6705 - val_loss: 0.1836 - val_accuracy: 0.5847
# Epoch 12/50
# 44/44 [==============================] - 29s 649ms/step - loss: 0.1526 - accuracy: 0.6700 - val_loss: 0.2382 - val_accuracy: 0.4958
# Epoch 13/50
# 44/44 [==============================] - 29s 649ms/step - loss: 0.1425 - accuracy: 0.6968 - val_loss: 0.2220 - val_accuracy: 0.5378
# Epoch 14/50
# 44/44 [==============================] - 29s 651ms/step - loss: 0.1358 - accuracy: 0.7069 - val_loss: 0.1990 - val_accuracy: 0.5742
# Epoch 15/50
# 44/44 [==============================] - 29s 656ms/step - loss: 0.1307 - accuracy: 0.7198 - val_loss: 0.1715 - val_accuracy: 0.6285
# Epoch 16/50
# 44/44 [==============================] - 29s 667ms/step - loss: 0.1245 - accuracy: 0.7297 - val_loss: 0.1949 - val_accuracy: 0.5893
# Epoch 17/50
# 44/44 [==============================] - 29s 658ms/step - loss: 0.1205 - accuracy: 0.7438 - val_loss: 0.1672 - val_accuracy: 0.6263
# Epoch 18/50
# 44/44 [==============================] - 29s 671ms/step - loss: 0.1155 - accuracy: 0.7532 - val_loss: 0.1800 - val_accuracy: 0.6226
# Epoch 19/50
# 44/44 [==============================] - 29s 670ms/step - loss: 0.1142 - accuracy: 0.7558 - val_loss: 0.1612 - val_accuracy: 0.6464
# Epoch 20/50
# 44/44 [==============================] - 29s 665ms/step - loss: 0.1049 - accuracy: 0.7778 - val_loss: 0.1531 - val_accuracy: 0.6674
# Epoch 21/50
# 44/44 [==============================] - 30s 674ms/step - loss: 0.1007 - accuracy: 0.7868 - val_loss: 0.1459 - val_accuracy: 0.6720
# Epoch 22/50
# 44/44 [==============================] - 29s 666ms/step - loss: 0.0991 - accuracy: 0.7950 - val_loss: 0.1385 - val_accuracy: 0.6936
# Epoch 23/50
# 44/44 [==============================] - 29s 663ms/step - loss: 0.0951 - accuracy: 0.8051 - val_loss: 0.1483 - val_accuracy: 0.6723
# Epoch 24/50
# 44/44 [==============================] - 30s 677ms/step - loss: 0.0876 - accuracy: 0.8290 - val_loss: 0.1494 - val_accuracy: 0.6871
# Epoch 25/50
# 44/44 [==============================] - 31s 705ms/step - loss: 0.0822 - accuracy: 0.8409 - val_loss: 0.1662 - val_accuracy: 0.6643
# Epoch 26/50
# 44/44 [==============================] - 32s 732ms/step - loss: 0.0784 - accuracy: 0.8506 - val_loss: 0.1342 - val_accuracy: 0.7090
# Epoch 27/50
# 44/44 [==============================] - 33s 745ms/step - loss: 0.0730 - accuracy: 0.8634 - val_loss: 0.1163 - val_accuracy: 0.7451
# Epoch 28/50
# 44/44 [==============================] - 33s 744ms/step - loss: 0.0663 - accuracy: 0.8831 - val_loss: 0.1107 - val_accuracy: 0.7633
# Epoch 29/50
# 44/44 [==============================] - 33s 747ms/step - loss: 0.0639 - accuracy: 0.8895 - val_loss: 0.1092 - val_accuracy: 0.7624
# Epoch 30/50
# 44/44 [==============================] - 37s 836ms/step - loss: 0.0620 - accuracy: 0.8908 - val_loss: 0.1059 - val_accuracy: 0.7828
# Epoch 31/50
# 44/44 [==============================] - 36s 815ms/step - loss: 0.0576 - accuracy: 0.9033 - val_loss: 0.1055 - val_accuracy: 0.7797
# Epoch 32/50
# 44/44 [==============================] - 34s 768ms/step - loss: 0.0532 - accuracy: 0.9140 - val_loss: 0.1047 - val_accuracy: 0.7951
# Epoch 33/50
# 44/44 [==============================] - 34s 782ms/step - loss: 0.0486 - accuracy: 0.9256 - val_loss: 0.1060 - val_accuracy: 0.7853
# Epoch 34/50
# 44/44 [==============================] - 34s 769ms/step - loss: 0.0449 - accuracy: 0.9318 - val_loss: 0.1497 - val_accuracy: 0.7164
# Epoch 35/50
# 44/44 [==============================] - 35s 802ms/step - loss: 0.0410 - accuracy: 0.9421 - val_loss: 0.1096 - val_accuracy: 0.7846
# Epoch 36/50
# 44/44 [==============================] - 35s 795ms/step - loss: 0.0391 - accuracy: 0.9449 - val_loss: 0.1400 - val_accuracy: 0.7470
# Epoch 37/50
# 44/44 [==============================] - 34s 779ms/step - loss: 0.0428 - accuracy: 0.9301 - val_loss: 0.0967 - val_accuracy: 0.8078
# Epoch 38/50
# 44/44 [==============================] - 35s 800ms/step - loss: 0.0329 - accuracy: 0.9586 - val_loss: 0.0934 - val_accuracy: 0.8294
# Epoch 39/50
# 44/44 [==============================] - 35s 795ms/step - loss: 0.0292 - accuracy: 0.9646 - val_loss: 0.1047 - val_accuracy: 0.8136
# Epoch 40/50
# 44/44 [==============================] - 34s 768ms/step - loss: 0.0283 - accuracy: 0.9652 - val_loss: 0.0886 - val_accuracy: 0.8386
# Epoch 41/50
# 44/44 [==============================] - 33s 757ms/step - loss: 0.0258 - accuracy: 0.9701 - val_loss: 0.1036 - val_accuracy: 0.8189
# Epoch 42/50
# 44/44 [==============================] - 33s 746ms/step - loss: 0.0259 - accuracy: 0.9661 - val_loss: 0.1062 - val_accuracy: 0.8226
# Epoch 43/50
# 44/44 [==============================] - 33s 754ms/step - loss: 0.0274 - accuracy: 0.9631 - val_loss: 0.0869 - val_accuracy: 0.8386
# Epoch 44/50
# 44/44 [==============================] - 33s 746ms/step - loss: 0.0209 - accuracy: 0.9761 - val_loss: 0.0874 - val_accuracy: 0.8500
# Epoch 45/50
# 44/44 [==============================] - 31s 708ms/step - loss: 0.0176 - accuracy: 0.9816 - val_loss: 0.0780 - val_accuracy: 0.8658
# Epoch 46/50
# 44/44 [==============================] - 30s 674ms/step - loss: 0.0169 - accuracy: 0.9818 - val_loss: 0.0861 - val_accuracy: 0.8556
# Epoch 47/50
# 44/44 [==============================] - 29s 652ms/step - loss: 0.0173 - accuracy: 0.9816 - val_loss: 0.0898 - val_accuracy: 0.8479
# Epoch 48/50
# 44/44 [==============================] - 28s 639ms/step - loss: 0.0173 - accuracy: 0.9799 - val_loss: 0.1080 - val_accuracy: 0.8217
# Epoch 49/50
# 44/44 [==============================] - 28s 639ms/step - loss: 0.0144 - accuracy: 0.9836 - val_loss: 0.0853 - val_accuracy: 0.8578
# Epoch 50/50
# 44/44 [==============================] - 28s 644ms/step - loss: 0.0199 - accuracy: 0.9729 - val_loss: 0.1062 - val_accuracy: 0.8325

# %%
def inv_Transform_result(y_pred):    
    y_pred = y_pred.argmax(axis=1)
    y_pred = encoder.inverse_transform(y_pred)
    return y_pred



y_pred=cnn_model.predict(X_test)

score = cnn_model.evaluate(X_test, y_test, verbose = 0) 

print('Test loss:', score[0]) 
print('Test accuracy:', score[1])

Y_pred=inv_Transform_result(y_pred)
Y_test = inv_Transform_result(y_test)




from sklearn.metrics import confusion_matrix


plt.figure(figsize=(10,10))
cm = confusion_matrix(Y_test, Y_pred,normalize='true')
f = sns.heatmap(cm, annot=True,xticklabels=encoder.classes_,yticklabels=encoder.classes_)
plt.show()
# Out:
# Test loss: 0.10621866583824158
# Test accuracy: 0.8324590921401978

# %%
dummy_cnn = Model(inputs=cnn_model.input,outputs=cnn_model.layers[8].output)
y_viz = dummy_cnn.predict(X_train)

# %%
from sklearn.manifold import TSNE

X_t_sne = TSNE(n_components=2, learning_rate='auto',verbose=1, perplexity=40, n_iter=300).fit_transform(y_viz)

tSNEdf = pd.DataFrame(data = X_t_sne, columns = ['T-SNE component 1', 'T-SNE component 2'])

tSNEdf['Fault']=inv_Transform_result(y_train)


# Plot the PC-1 and PC-2
fig, ax = plt.subplots(figsize=(10,10))
sns.scatterplot(x=tSNEdf['T-SNE component 1'],y=tSNEdf['T-SNE component 2'],hue='Fault',
    data=tSNEdf,
    legend="full",
    alpha=0.3)
plt.show()
# Out:
# /Users/divyanshuchaudhari/miniforge3/envs/pytorch_m1/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 12964 samples in 0.001s...
# [t-SNE] Computed neighbors for 12964 samples in 2.590s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 12964
# [t-SNE] Computed conditional probabilities for sample 2000 / 12964
# [t-SNE] Computed conditional probabilities for sample 3000 / 12964
# [t-SNE] Computed conditional probabilities for sample 4000 / 12964
# [t-SNE] Computed conditional probabilities for sample 5000 / 12964
# [t-SNE] Computed conditional probabilities for sample 6000 / 12964
# [t-SNE] Computed conditional probabilities for sample 7000 / 12964
# [t-SNE] Computed conditional probabilities for sample 8000 / 12964
# [t-SNE] Computed conditional probabilities for sample 9000 / 12964
# [t-SNE] Computed conditional probabilities for sample 10000 / 12964
# [t-SNE] Computed conditional probabilities for sample 11000 / 12964
# [t-SNE] Computed conditional probabilities for sample 12000 / 12964
# [t-SNE] Computed conditional probabilities for sample 12964 / 12964
# [t-SNE] Mean sigma: 0.113157
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 69.615334
# [t-SNE] KL divergence after 300 iterations: 2.390032
