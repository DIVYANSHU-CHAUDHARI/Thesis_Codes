# %%
import scipy.io
import seaborn as sns
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('2hp_all_faults_1750.csv')

# %%
df = df[df['fault'] != '21_OR2']
df = df[df['fault'] != '21_OR3']
df = df[df['fault'] != '7_OR2']
df = df[df['fault'] != '7_OR3']

# %%
df['fault'].unique()
# Out:
# array(['21_BA', 'N', '21_IR', '21_OR1', '14_BA', '7_IR', '7_OR1', '14_IR',
#        '7_BA', '14_OR1'], dtype=object)

# %%
np.random.normal(0, 1, df.shape[0])
signal_energy = np.mean(df['DE_data']**2)
print(signal_energy)
white_noise_1 = np.clip(np.random.normal(0, 1, df.shape[0]), -1.2, 1.1) # -4.5
signal_energy = np.mean(df['DE_data']**2)
noise_energy = np.mean(white_noise_1**2)
SNR =  10*np.log10(signal_energy/noise_energy)
print(SNR)
# Out:
# 0.23307969559679226
# -4.1538710575583035

# %%
df['DE_data'] = df['DE_data'] + white_noise_1

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

win_len=1200
stride=300

X=[]
Y=[]


for k in df['fault'].unique():
    
    df_temp_2 = df[df['fault']==k]
    
    for i in np.arange(0,len(df_temp_2)-(win_len),stride):
        temp = df_temp_2.iloc[i:i+win_len,:-1].values
        temp = temp.reshape((1,-1))
        X.append(temp)
        Y.append(df_temp_2.iloc[i+win_len,-1])
    
X=np.array(X)
print(X.shape)
X=X.reshape((X.shape[0],-1,1))
#X = np.repeat(X, 3, axis=3) # To repeat into 3 chanel format


Y=np.array(Y)
encoder= LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)
OHE_Y = to_categorical(encoded_Y)
# Out:
# (16205, 1, 1200)

# %%
X.shape
# Out:
# (16205, 1200, 1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,OHE_Y,test_size=0.2,shuffle=True)

# %%
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Input,Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D,Conv1D,MaxPooling1D
from tensorflow.keras.layers import LSTM
from keras.layers import BatchNormalization

# from tensorflow.keras.models import load_model
# cnn_model = load_model(r'H:\Gear Fault\Trained Model\CNN_model_gear.h5')



no_classes = len(df['fault'].unique())

cnn_model = Sequential()
cnn_model.add(Conv1D(filters=16, kernel_size=200, activation='relu', input_shape=(X.shape[1],X.shape[2])))
cnn_model.add(MaxPooling1D(pool_size=2))
cnn_model.add(BatchNormalization())
cnn_model.add(Conv1D(filters=32, kernel_size=100, activation='relu'))
cnn_model.add(MaxPooling1D(pool_size=2))
cnn_model.add(BatchNormalization())
cnn_model.add(Conv1D(filters=64, kernel_size=50, activation='relu'))
# cnn_model = Sequential()
# cnn_model.add(Conv1D(filters=64, kernel_size=100, activation='relu', input_shape=(X.shape[1],X.shape[2])))
# cnn_model.add(Conv1D(filters=32, kernel_size=50, activation='relu'))

# cnn_model.add(MaxPooling1D(pool_size=4))
# cnn_model.add(MaxPooling1D(pool_size=4))
cnn_model.add(Dropout(0.5))
cnn_model.add(LSTM(32))
# cnn_model.add(Flatten())
# cnn_model.add(Dense(40, activation='relu'))
cnn_model.add(Dense(no_classes, activation='softmax'))

cnn_model.summary()

cnn_model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 1001, 16)          3216
#
#  max_pooling1d (MaxPooling1D  (None, 500, 16)          0
#  )
#
#  batch_normalization (BatchN  (None, 500, 16)          64
#  ormalization)
#
#  conv1d_1 (Conv1D)           (None, 401, 32)           51232
#
#  max_pooling1d_1 (MaxPooling  (None, 200, 32)          0
#  1D)
#
#  batch_normalization_1 (Batc  (None, 200, 32)          128
#  hNormalization)
#
#  conv1d_2 (Conv1D)           (None, 151, 64)           102464
#
#  dropout (Dropout)           (None, 151, 64)           0
#
#  lstm (LSTM)                 (None, 32)                12416
#
#  dense (Dense)               (None, 10)                330
#
# =================================================================
# Total params: 169,850
# Trainable params: 169,754
# Non-trainable params: 96
# _________________________________________________________________

# %%
batch_size =300
epochs = 70
history = cnn_model.fit(X_train, y_train, batch_size=batch_size,epochs=epochs,verbose=1,validation_split=0.1,shuffle=True)
# Out:
# Epoch 1/70
# 2022-03-01 00:07:08.166840: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 39/39 [==============================] - 22s 546ms/step - loss: 1.8311 - accuracy: 0.3188 - val_loss: 2.5592 - val_accuracy: 0.2274
# Epoch 2/70
# 39/39 [==============================] - 22s 553ms/step - loss: 1.4258 - accuracy: 0.4670 - val_loss: 2.8313 - val_accuracy: 0.3138
# Epoch 3/70
# 39/39 [==============================] - 24s 609ms/step - loss: 1.1910 - accuracy: 0.5496 - val_loss: 3.8140 - val_accuracy: 0.3261
# Epoch 4/70
# 39/39 [==============================] - 24s 604ms/step - loss: 1.1168 - accuracy: 0.5708 - val_loss: 4.1070 - val_accuracy: 0.3246
# Epoch 5/70
# 39/39 [==============================] - 23s 603ms/step - loss: 1.0273 - accuracy: 0.6110 - val_loss: 4.5977 - val_accuracy: 0.3454
# Epoch 6/70
# 39/39 [==============================] - 24s 621ms/step - loss: 0.9770 - accuracy: 0.6243 - val_loss: 4.6076 - val_accuracy: 0.3470
# Epoch 7/70
# 39/39 [==============================] - 25s 630ms/step - loss: 0.9116 - accuracy: 0.6541 - val_loss: 4.0837 - val_accuracy: 0.3601
# Epoch 8/70
# 39/39 [==============================] - 25s 654ms/step - loss: 0.8812 - accuracy: 0.6587 - val_loss: 2.6942 - val_accuracy: 0.4048
# Epoch 9/70
# 39/39 [==============================] - 25s 633ms/step - loss: 0.8412 - accuracy: 0.6788 - val_loss: 2.0054 - val_accuracy: 0.4873
# Epoch 10/70
# 39/39 [==============================] - 25s 636ms/step - loss: 0.8424 - accuracy: 0.6796 - val_loss: 2.3432 - val_accuracy: 0.4325
# Epoch 11/70
# 39/39 [==============================] - 25s 645ms/step - loss: 0.8035 - accuracy: 0.6889 - val_loss: 1.8718 - val_accuracy: 0.5143
# Epoch 12/70
# 39/39 [==============================] - 26s 659ms/step - loss: 0.7772 - accuracy: 0.6956 - val_loss: 1.4881 - val_accuracy: 0.5544
# Epoch 13/70
# 39/39 [==============================] - 26s 658ms/step - loss: 0.7497 - accuracy: 0.7090 - val_loss: 1.3515 - val_accuracy: 0.5652
# Epoch 14/70
# 39/39 [==============================] - 26s 662ms/step - loss: 0.7155 - accuracy: 0.7232 - val_loss: 1.2670 - val_accuracy: 0.5598
# Epoch 15/70
# 39/39 [==============================] - 26s 664ms/step - loss: 0.6944 - accuracy: 0.7300 - val_loss: 1.2172 - val_accuracy: 0.5821
# Epoch 16/70
# 39/39 [==============================] - 26s 664ms/step - loss: 0.6893 - accuracy: 0.7288 - val_loss: 2.0398 - val_accuracy: 0.5112
# Epoch 17/70
# 39/39 [==============================] - 26s 664ms/step - loss: 0.7130 - accuracy: 0.7236 - val_loss: 0.9137 - val_accuracy: 0.6492
# Epoch 18/70
# 39/39 [==============================] - 26s 661ms/step - loss: 0.7235 - accuracy: 0.7184 - val_loss: 1.1042 - val_accuracy: 0.6237
# Epoch 19/70
# 39/39 [==============================] - 26s 671ms/step - loss: 0.6626 - accuracy: 0.7376 - val_loss: 0.8052 - val_accuracy: 0.6993
# Epoch 20/70
# 39/39 [==============================] - 27s 696ms/step - loss: 0.6342 - accuracy: 0.7476 - val_loss: 1.0397 - val_accuracy: 0.6153
# Epoch 21/70
# 39/39 [==============================] - 29s 755ms/step - loss: 0.6135 - accuracy: 0.7565 - val_loss: 1.1181 - val_accuracy: 0.6230
# Epoch 22/70
# 39/39 [==============================] - 31s 809ms/step - loss: 0.5864 - accuracy: 0.7691 - val_loss: 1.1071 - val_accuracy: 0.6022
# Epoch 23/70
# 39/39 [==============================] - 33s 859ms/step - loss: 0.5700 - accuracy: 0.7743 - val_loss: 1.0995 - val_accuracy: 0.6106
# Epoch 24/70
# 39/39 [==============================] - 35s 894ms/step - loss: 0.5743 - accuracy: 0.7741 - val_loss: 0.9848 - val_accuracy: 0.6608
# Epoch 25/70
# 39/39 [==============================] - 36s 928ms/step - loss: 0.5654 - accuracy: 0.7801 - val_loss: 1.1476 - val_accuracy: 0.6268
# Epoch 26/70
# 39/39 [==============================] - 37s 939ms/step - loss: 0.5203 - accuracy: 0.7984 - val_loss: 1.0414 - val_accuracy: 0.6523
# Epoch 27/70
# 39/39 [==============================] - 38s 964ms/step - loss: 0.4702 - accuracy: 0.8185 - val_loss: 0.8847 - val_accuracy: 0.6731
# Epoch 28/70
# 39/39 [==============================] - 38s 987ms/step - loss: 0.4732 - accuracy: 0.8175 - val_loss: 0.8518 - val_accuracy: 0.6924
# Epoch 29/70
# 39/39 [==============================] - 40s 1s/step - loss: 0.4338 - accuracy: 0.8317 - val_loss: 0.8529 - val_accuracy: 0.7093
# Epoch 30/70
# 39/39 [==============================] - 40s 1s/step - loss: 0.4406 - accuracy: 0.8323 - val_loss: 0.7599 - val_accuracy: 0.7224
# Epoch 31/70
# 39/39 [==============================] - 40s 1s/step - loss: 0.4074 - accuracy: 0.8442 - val_loss: 0.8694 - val_accuracy: 0.6939
# Epoch 32/70
# 39/39 [==============================] - 41s 1s/step - loss: 0.3719 - accuracy: 0.8609 - val_loss: 0.8346 - val_accuracy: 0.7047
# Epoch 33/70
# 39/39 [==============================] - 41s 1s/step - loss: 0.3556 - accuracy: 0.8647 - val_loss: 0.7668 - val_accuracy: 0.7247
# Epoch 34/70
# 39/39 [==============================] - 41s 1s/step - loss: 0.3476 - accuracy: 0.8731 - val_loss: 0.8616 - val_accuracy: 0.7101
# Epoch 35/70
# 39/39 [==============================] - 41s 1s/step - loss: 0.3056 - accuracy: 0.8875 - val_loss: 1.1757 - val_accuracy: 0.6515
# Epoch 36/70
# 39/39 [==============================] - 41s 1s/step - loss: 0.2861 - accuracy: 0.8966 - val_loss: 0.8215 - val_accuracy: 0.7201
# Epoch 37/70
# 39/39 [==============================] - 41s 1s/step - loss: 0.2696 - accuracy: 0.9046 - val_loss: 0.6923 - val_accuracy: 0.7610
# Epoch 38/70
# 39/39 [==============================] - 41s 1s/step - loss: 0.2338 - accuracy: 0.9211 - val_loss: 0.6804 - val_accuracy: 0.7702
# Epoch 39/70
# 39/39 [==============================] - 41s 1s/step - loss: 0.2189 - accuracy: 0.9269 - val_loss: 0.7070 - val_accuracy: 0.7749
# Epoch 40/70
# 39/39 [==============================] - 40s 1s/step - loss: 0.1866 - accuracy: 0.9392 - val_loss: 0.7393 - val_accuracy: 0.7702
# Epoch 41/70
# 39/39 [==============================] - 41s 1s/step - loss: 0.1763 - accuracy: 0.9445 - val_loss: 0.6194 - val_accuracy: 0.8011
# Epoch 42/70
# 39/39 [==============================] - 40s 1s/step - loss: 0.1589 - accuracy: 0.9487 - val_loss: 0.6403 - val_accuracy: 0.8049
# Epoch 43/70
# 39/39 [==============================] - 40s 1s/step - loss: 0.1633 - accuracy: 0.9488 - val_loss: 0.7844 - val_accuracy: 0.7625
# Epoch 44/70
# 39/39 [==============================] - 40s 1s/step - loss: 0.1403 - accuracy: 0.9571 - val_loss: 0.9846 - val_accuracy: 0.7433
# Epoch 45/70
# 39/39 [==============================] - 40s 1s/step - loss: 0.2227 - accuracy: 0.9265 - val_loss: 0.8664 - val_accuracy: 0.7502
# Epoch 46/70
# 39/39 [==============================] - 40s 1s/step - loss: 0.1564 - accuracy: 0.9492 - val_loss: 0.6402 - val_accuracy: 0.8057
# Epoch 47/70
# 39/39 [==============================] - 39s 1s/step - loss: 0.1265 - accuracy: 0.9604 - val_loss: 0.7288 - val_accuracy: 0.7880
# Epoch 48/70
# 39/39 [==============================] - 39s 1s/step - loss: 0.1069 - accuracy: 0.9698 - val_loss: 0.8030 - val_accuracy: 0.7803
# Epoch 49/70
# 39/39 [==============================] - 40s 1s/step - loss: 0.0897 - accuracy: 0.9727 - val_loss: 0.5676 - val_accuracy: 0.8327
# Epoch 50/70
# 39/39 [==============================] - 40s 1s/step - loss: 0.0716 - accuracy: 0.9805 - val_loss: 0.6576 - val_accuracy: 0.8211
# Epoch 51/70
# 39/39 [==============================] - 41s 1s/step - loss: 0.0603 - accuracy: 0.9841 - val_loss: 0.6237 - val_accuracy: 0.8227
# Epoch 52/70
# 39/39 [==============================] - 42s 1s/step - loss: 0.0632 - accuracy: 0.9823 - val_loss: 0.8514 - val_accuracy: 0.7849
# Epoch 53/70
# 39/39 [==============================] - 39s 1s/step - loss: 0.0677 - accuracy: 0.9804 - val_loss: 0.7625 - val_accuracy: 0.7918
# Epoch 54/70
# 39/39 [==============================] - 39s 995ms/step - loss: 0.0627 - accuracy: 0.9826 - val_loss: 0.7219 - val_accuracy: 0.8065
# Epoch 55/70
# 39/39 [==============================] - 38s 985ms/step - loss: 0.0622 - accuracy: 0.9816 - val_loss: 0.5719 - val_accuracy: 0.8435
# Epoch 56/70
# 39/39 [==============================] - 38s 987ms/step - loss: 0.0421 - accuracy: 0.9893 - val_loss: 0.5925 - val_accuracy: 0.8288
# Epoch 57/70
# 39/39 [==============================] - 39s 989ms/step - loss: 0.0377 - accuracy: 0.9906 - val_loss: 0.6488 - val_accuracy: 0.8342
# Epoch 58/70
# 39/39 [==============================] - 39s 994ms/step - loss: 0.0321 - accuracy: 0.9918 - val_loss: 0.6010 - val_accuracy: 0.8450
# Epoch 59/70
# 39/39 [==============================] - 38s 986ms/step - loss: 0.0402 - accuracy: 0.9892 - val_loss: 0.6381 - val_accuracy: 0.8358
# Epoch 60/70
# 39/39 [==============================] - 39s 1s/step - loss: 0.0425 - accuracy: 0.9878 - val_loss: 0.6833 - val_accuracy: 0.8173
# Epoch 61/70
# 39/39 [==============================] - 39s 999ms/step - loss: 0.0436 - accuracy: 0.9862 - val_loss: 0.6397 - val_accuracy: 0.8381
# Epoch 62/70
# 39/39 [==============================] - 39s 992ms/step - loss: 0.0541 - accuracy: 0.9845 - val_loss: 0.6386 - val_accuracy: 0.8335
# Epoch 63/70
# 39/39 [==============================] - 38s 970ms/step - loss: 0.0480 - accuracy: 0.9856 - val_loss: 0.6813 - val_accuracy: 0.8234
# Epoch 64/70
# 39/39 [==============================] - 38s 967ms/step - loss: 0.0422 - accuracy: 0.9883 - val_loss: 0.5919 - val_accuracy: 0.8543
# Epoch 65/70
# 39/39 [==============================] - 38s 974ms/step - loss: 0.0407 - accuracy: 0.9888 - val_loss: 0.6504 - val_accuracy: 0.8381
# Epoch 66/70
# 39/39 [==============================] - 38s 970ms/step - loss: 0.0343 - accuracy: 0.9908 - val_loss: 0.7414 - val_accuracy: 0.8242
# Epoch 67/70
# 39/39 [==============================] - 38s 983ms/step - loss: 0.0295 - accuracy: 0.9924 - val_loss: 0.6358 - val_accuracy: 0.8443
# Epoch 68/70
# 39/39 [==============================] - 38s 976ms/step - loss: 0.0355 - accuracy: 0.9898 - val_loss: 0.7325 - val_accuracy: 0.8265
# Epoch 69/70
# 39/39 [==============================] - 38s 983ms/step - loss: 0.0305 - accuracy: 0.9924 - val_loss: 0.5811 - val_accuracy: 0.8489
# Epoch 70/70
# 39/39 [==============================] - 38s 979ms/step - loss: 0.0215 - accuracy: 0.9943 - val_loss: 0.6400 - val_accuracy: 0.8427

# %%
def inv_Transform_result(y_pred):    
    y_pred = y_pred.argmax(axis=1)
    y_pred = encoder.inverse_transform(y_pred)
    return y_pred



y_pred=cnn_model.predict(X_test)

score = cnn_model.evaluate(X_test, y_test, verbose = 0) 

print('Test loss:', score[0]) 
print('Test accuracy:', score[1])

Y_pred=inv_Transform_result(y_pred)
Y_test = inv_Transform_result(y_test)




from sklearn.metrics import confusion_matrix


plt.figure(figsize=(10,10))
cm = confusion_matrix(Y_test, Y_pred,normalize='true')
f = sns.heatmap(cm, annot=True,xticklabels=encoder.classes_,yticklabels=encoder.classes_)
plt.show()
# Out:
# Test loss: 0.6144278049468994
# Test accuracy: 0.8485035300254822

# %%
dummy_cnn = Model(inputs=cnn_model.input,outputs=cnn_model.layers[8].output)
y_viz = dummy_cnn.predict(X_train)

# %%
from sklearn.manifold import TSNE

X_t_sne = TSNE(n_components=2, learning_rate='auto',verbose=1, perplexity=40, n_iter=300).fit_transform(y_viz)

tSNEdf = pd.DataFrame(data = X_t_sne, columns = ['T-SNE component 1', 'T-SNE component 2'])

tSNEdf['Fault']=inv_Transform_result(y_train)


# Plot the PC-1 and PC-2
fig, ax = plt.subplots(figsize=(10,10))
sns.scatterplot(x=tSNEdf['T-SNE component 1'],y=tSNEdf['T-SNE component 2'],hue='Fault',
    data=tSNEdf,
    legend="full",
    alpha=0.3)
plt.show()
# Out:
# /Users/divyanshuchaudhari/miniforge3/envs/pytorch_m1/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 12964 samples in 0.001s...
# [t-SNE] Computed neighbors for 12964 samples in 2.876s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 12964
# [t-SNE] Computed conditional probabilities for sample 2000 / 12964
# [t-SNE] Computed conditional probabilities for sample 3000 / 12964
# [t-SNE] Computed conditional probabilities for sample 4000 / 12964
# [t-SNE] Computed conditional probabilities for sample 5000 / 12964
# [t-SNE] Computed conditional probabilities for sample 6000 / 12964
# [t-SNE] Computed conditional probabilities for sample 7000 / 12964
# [t-SNE] Computed conditional probabilities for sample 8000 / 12964
# [t-SNE] Computed conditional probabilities for sample 9000 / 12964
# [t-SNE] Computed conditional probabilities for sample 10000 / 12964
# [t-SNE] Computed conditional probabilities for sample 11000 / 12964
# [t-SNE] Computed conditional probabilities for sample 12000 / 12964
# [t-SNE] Computed conditional probabilities for sample 12964 / 12964
# [t-SNE] Mean sigma: 0.369545
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 69.787750
# [t-SNE] KL divergence after 300 iterations: 2.377933
