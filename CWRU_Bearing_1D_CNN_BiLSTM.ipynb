# %%
import scipy.io
import seaborn as sns
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('2hp_all_faults_1750.csv')

# %%
df = df[df['fault'] != '21_OR2']
df = df[df['fault'] != '21_OR3']
df = df[df['fault'] != '7_OR2']
df = df[df['fault'] != '7_OR3']

# %%
df['fault'].unique()
# Out:
# array(['21_BA', 'N', '21_IR', '21_OR1', '14_BA', '7_IR', '7_OR1', '14_IR',
#        '7_BA', '14_OR1'], dtype=object)

# %%
np.random.normal(0, 1, df.shape[0])
signal_energy = np.mean(df['DE_data']**2)
print(signal_energy)
white_noise_1 = np.clip(np.random.normal(0, 1, df.shape[0]), -1.2, 1.035) # -4.5
signal_energy = np.mean(df['DE_data']**2)
noise_energy = np.mean(white_noise_1**2)
SNR =  10*np.log10(signal_energy/noise_energy)
print(SNR)
# Out:
# 0.23307969559679226
# -4.009297484111623

# %%
df['DE_data'] = df['DE_data'] + white_noise_1

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

win_len=1200
stride=300

X=[]
Y=[]


for k in df['fault'].unique():
    
    df_temp_2 = df[df['fault']==k]
    
    for i in np.arange(0,len(df_temp_2)-(win_len),stride):
        temp = df_temp_2.iloc[i:i+win_len,:-1].values
        temp = temp.reshape((1,-1))
        X.append(temp)
        Y.append(df_temp_2.iloc[i+win_len,-1])
    
X=np.array(X)
print(X.shape)
X=X.reshape((X.shape[0],-1,1))
#X = np.repeat(X, 3, axis=3) # To repeat into 3 chanel format


Y=np.array(Y)
encoder= LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)
OHE_Y = to_categorical(encoded_Y)
# Out:
# (16205, 1, 1200)

# %%
X.shape
# Out:
# (16205, 1200, 1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,OHE_Y,test_size=0.2,shuffle=True)

# %%
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Input,Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D,Conv1D,MaxPooling1D
from tensorflow.keras.layers import LSTM,Bidirectional
from keras.layers import BatchNormalization

# from tensorflow.keras.models import load_model
# cnn_model = load_model(r'H:\Gear Fault\Trained Model\CNN_model_gear.h5')



no_classes = len(df['fault'].unique())

cnn_model = Sequential()
cnn_model.add(Conv1D(filters=16, kernel_size=200, activation='relu', input_shape=(X.shape[1],X.shape[2])))
cnn_model.add(MaxPooling1D(pool_size=2))
cnn_model.add(BatchNormalization())
cnn_model.add(Conv1D(filters=32, kernel_size=100, activation='relu'))
cnn_model.add(MaxPooling1D(pool_size=2))
cnn_model.add(BatchNormalization())
cnn_model.add(Conv1D(filters=64, kernel_size=50, activation='relu'))
# cnn_model = Sequential()
# cnn_model.add(Conv1D(filters=64, kernel_size=100, activation='relu', input_shape=(X.shape[1],X.shape[2])))
# cnn_model.add(Conv1D(filters=32, kernel_size=50, activation='relu'))

# cnn_model.add(MaxPooling1D(pool_size=4))
# cnn_model.add(MaxPooling1D(pool_size=4))
cnn_model.add(Dropout(0.5))
cnn_model.add(Bidirectional(LSTM(32)))
# cnn_model.add(Flatten()) v
# cnn_model.add(Dense(40, activation='relu'))
cnn_model.add(Dense(no_classes, activation='softmax'))

cnn_model.summary()

cnn_model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 1001, 16)          3216
#
#  max_pooling1d (MaxPooling1D  (None, 500, 16)          0
#  )
#
#  batch_normalization (BatchN  (None, 500, 16)          64
#  ormalization)
#
#  conv1d_1 (Conv1D)           (None, 401, 32)           51232
#
#  max_pooling1d_1 (MaxPooling  (None, 200, 32)          0
#  1D)
#
#  batch_normalization_1 (Batc  (None, 200, 32)          128
#  hNormalization)
#
#  conv1d_2 (Conv1D)           (None, 151, 64)           102464
#
#  dropout (Dropout)           (None, 151, 64)           0
#
#  bidirectional (Bidirectiona  (None, 64)               24832
#  l)
#
#  dense (Dense)               (None, 10)                650
#
# =================================================================
# Total params: 182,586
# Trainable params: 182,490
# Non-trainable params: 96
# _________________________________________________________________

# %%
batch_size =300
epochs = 70
history = cnn_model.fit(X_train, y_train, batch_size=batch_size,epochs=epochs,verbose=1,validation_split=0.1,shuffle=True)
# Out:
# Epoch 1/70
# 2022-03-14 11:29:24.657035: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 39/39 [==============================] - 23s 566ms/step - loss: 1.6896 - accuracy: 0.3709 - val_loss: 4.2535 - val_accuracy: 0.1542
# Epoch 2/70
# 39/39 [==============================] - 22s 575ms/step - loss: 1.1402 - accuracy: 0.5762 - val_loss: 3.3702 - val_accuracy: 0.3246
# Epoch 3/70
# 39/39 [==============================] - 24s 606ms/step - loss: 0.9253 - accuracy: 0.6470 - val_loss: 3.8803 - val_accuracy: 0.3732
# Epoch 4/70
# 39/39 [==============================] - 25s 630ms/step - loss: 0.8399 - accuracy: 0.6786 - val_loss: 4.6256 - val_accuracy: 0.3685
# Epoch 5/70
# 39/39 [==============================] - 25s 631ms/step - loss: 0.7787 - accuracy: 0.6873 - val_loss: 4.4483 - val_accuracy: 0.3940
# Epoch 6/70
# 39/39 [==============================] - 25s 646ms/step - loss: 0.7260 - accuracy: 0.7148 - val_loss: 4.0813 - val_accuracy: 0.3855
# Epoch 7/70
# 39/39 [==============================] - 26s 658ms/step - loss: 0.6877 - accuracy: 0.7302 - val_loss: 4.6593 - val_accuracy: 0.4040
# Epoch 8/70
# 39/39 [==============================] - 26s 660ms/step - loss: 0.6473 - accuracy: 0.7428 - val_loss: 3.0398 - val_accuracy: 0.4402
# Epoch 9/70
# 39/39 [==============================] - 26s 671ms/step - loss: 0.6270 - accuracy: 0.7544 - val_loss: 2.4928 - val_accuracy: 0.4934
# Epoch 10/70
# 39/39 [==============================] - 26s 671ms/step - loss: 0.5934 - accuracy: 0.7690 - val_loss: 1.9812 - val_accuracy: 0.5258
# Epoch 11/70
# 39/39 [==============================] - 26s 675ms/step - loss: 0.5541 - accuracy: 0.7840 - val_loss: 1.6110 - val_accuracy: 0.5536
# Epoch 12/70
# 39/39 [==============================] - 27s 684ms/step - loss: 0.5238 - accuracy: 0.7987 - val_loss: 1.2354 - val_accuracy: 0.6284
# Epoch 13/70
# 39/39 [==============================] - 28s 710ms/step - loss: 0.5147 - accuracy: 0.7995 - val_loss: 1.2262 - val_accuracy: 0.6245
# Epoch 14/70
# 39/39 [==============================] - 27s 705ms/step - loss: 0.4449 - accuracy: 0.8270 - val_loss: 1.1335 - val_accuracy: 0.6492
# Epoch 15/70
# 39/39 [==============================] - 27s 686ms/step - loss: 0.4362 - accuracy: 0.8349 - val_loss: 0.9874 - val_accuracy: 0.6823
# Epoch 16/70
# 39/39 [==============================] - 27s 695ms/step - loss: 0.3904 - accuracy: 0.8561 - val_loss: 1.1176 - val_accuracy: 0.6654
# Epoch 17/70
# 39/39 [==============================] - 27s 698ms/step - loss: 0.3291 - accuracy: 0.8829 - val_loss: 0.9094 - val_accuracy: 0.6955
# Epoch 18/70
# 39/39 [==============================] - 27s 703ms/step - loss: 0.3123 - accuracy: 0.8911 - val_loss: 0.7921 - val_accuracy: 0.7294
# Epoch 19/70
# 39/39 [==============================] - 27s 705ms/step - loss: 0.3168 - accuracy: 0.8885 - val_loss: 0.9963 - val_accuracy: 0.6947
# Epoch 20/70
# 39/39 [==============================] - 27s 703ms/step - loss: 0.2832 - accuracy: 0.9019 - val_loss: 0.7562 - val_accuracy: 0.7525
# Epoch 21/70
# 39/39 [==============================] - 28s 705ms/step - loss: 0.2190 - accuracy: 0.9287 - val_loss: 0.7910 - val_accuracy: 0.7448
# Epoch 22/70
# 39/39 [==============================] - 28s 716ms/step - loss: 0.1555 - accuracy: 0.9554 - val_loss: 0.6663 - val_accuracy: 0.7818
# Epoch 23/70
# 39/39 [==============================] - 29s 755ms/step - loss: 0.1372 - accuracy: 0.9619 - val_loss: 0.7235 - val_accuracy: 0.7648
# Epoch 24/70
# 39/39 [==============================] - 31s 783ms/step - loss: 0.1167 - accuracy: 0.9674 - val_loss: 0.6289 - val_accuracy: 0.8034
# Epoch 25/70
# 39/39 [==============================] - 34s 867ms/step - loss: 0.0932 - accuracy: 0.9764 - val_loss: 0.7481 - val_accuracy: 0.7833
# Epoch 26/70
# 39/39 [==============================] - 35s 912ms/step - loss: 0.0794 - accuracy: 0.9800 - val_loss: 0.7446 - val_accuracy: 0.7918
# Epoch 27/70
# 39/39 [==============================] - 39s 995ms/step - loss: 0.0644 - accuracy: 0.9848 - val_loss: 0.6774 - val_accuracy: 0.8119
# Epoch 28/70
# 39/39 [==============================] - 37s 950ms/step - loss: 0.0585 - accuracy: 0.9863 - val_loss: 0.7195 - val_accuracy: 0.8034
# Epoch 29/70
# 39/39 [==============================] - 35s 899ms/step - loss: 0.0556 - accuracy: 0.9872 - val_loss: 0.7108 - val_accuracy: 0.8049
# Epoch 30/70
# 39/39 [==============================] - 34s 882ms/step - loss: 0.0544 - accuracy: 0.9868 - val_loss: 0.6910 - val_accuracy: 0.8072
# Epoch 31/70
# 39/39 [==============================] - 38s 988ms/step - loss: 0.0498 - accuracy: 0.9891 - val_loss: 0.8067 - val_accuracy: 0.7887
# Epoch 32/70
# 39/39 [==============================] - 36s 928ms/step - loss: 0.1110 - accuracy: 0.9645 - val_loss: 0.9322 - val_accuracy: 0.7695
# Epoch 33/70
# 39/39 [==============================] - 37s 954ms/step - loss: 0.0936 - accuracy: 0.9711 - val_loss: 1.2856 - val_accuracy: 0.7170
# Epoch 34/70
# 39/39 [==============================] - 41s 1s/step - loss: 0.0736 - accuracy: 0.9787 - val_loss: 0.6633 - val_accuracy: 0.8265
# Epoch 35/70
# 39/39 [==============================] - 40s 1s/step - loss: 0.0487 - accuracy: 0.9870 - val_loss: 0.6653 - val_accuracy: 0.8157
# Epoch 36/70
# 39/39 [==============================] - 42s 1s/step - loss: 0.0368 - accuracy: 0.9915 - val_loss: 0.6563 - val_accuracy: 0.8319
# Epoch 37/70
# 39/39 [==============================] - 43s 1s/step - loss: 0.0243 - accuracy: 0.9955 - val_loss: 0.7612 - val_accuracy: 0.8157
# Epoch 38/70
# 39/39 [==============================] - 42s 1s/step - loss: 0.0244 - accuracy: 0.9952 - val_loss: 0.5865 - val_accuracy: 0.8443
# Epoch 39/70
# 39/39 [==============================] - 43s 1s/step - loss: 0.0194 - accuracy: 0.9973 - val_loss: 0.6000 - val_accuracy: 0.8342
# Epoch 40/70
# 39/39 [==============================] - 43s 1s/step - loss: 0.0327 - accuracy: 0.9915 - val_loss: 1.1427 - val_accuracy: 0.7471
# Epoch 41/70
# 39/39 [==============================] - 45s 1s/step - loss: 0.0439 - accuracy: 0.9887 - val_loss: 0.6852 - val_accuracy: 0.8219
# Epoch 42/70
# 39/39 [==============================] - 46s 1s/step - loss: 0.0456 - accuracy: 0.9884 - val_loss: 0.6314 - val_accuracy: 0.8350
# Epoch 43/70
# 39/39 [==============================] - 44s 1s/step - loss: 0.0284 - accuracy: 0.9937 - val_loss: 0.6366 - val_accuracy: 0.8265
# Epoch 44/70
# 39/39 [==============================] - 45s 1s/step - loss: 0.0192 - accuracy: 0.9965 - val_loss: 0.6179 - val_accuracy: 0.8450
# Epoch 45/70
# 39/39 [==============================] - 45s 1s/step - loss: 0.0134 - accuracy: 0.9982 - val_loss: 0.6146 - val_accuracy: 0.8504
# Epoch 46/70
# 39/39 [==============================] - 47s 1s/step - loss: 0.0101 - accuracy: 0.9989 - val_loss: 0.5919 - val_accuracy: 0.8643
# Epoch 47/70
# 39/39 [==============================] - 46s 1s/step - loss: 0.0105 - accuracy: 0.9982 - val_loss: 0.6596 - val_accuracy: 0.8458
# Epoch 48/70
# 39/39 [==============================] - 49s 1s/step - loss: 0.0122 - accuracy: 0.9979 - val_loss: 0.7539 - val_accuracy: 0.8196
# Epoch 49/70
# 39/39 [==============================] - 65s 2s/step - loss: 0.0109 - accuracy: 0.9979 - val_loss: 0.7408 - val_accuracy: 0.8242
# Epoch 50/70
# 39/39 [==============================] - 56s 1s/step - loss: 0.0176 - accuracy: 0.9956 - val_loss: 0.7543 - val_accuracy: 0.8204
# Epoch 51/70
# 39/39 [==============================] - 59s 2s/step - loss: 0.0252 - accuracy: 0.9932 - val_loss: 0.9924 - val_accuracy: 0.7849
# Epoch 52/70
# 39/39 [==============================] - 55s 1s/step - loss: 0.0289 - accuracy: 0.9929 - val_loss: 1.0635 - val_accuracy: 0.7710
# Epoch 53/70
# 39/39 [==============================] - 57s 1s/step - loss: 0.0368 - accuracy: 0.9889 - val_loss: 0.6866 - val_accuracy: 0.8258
# Epoch 54/70
# 39/39 [==============================] - 58s 1s/step - loss: 0.0360 - accuracy: 0.9888 - val_loss: 0.9537 - val_accuracy: 0.7841
# Epoch 55/70
# 39/39 [==============================] - 60s 2s/step - loss: 0.0267 - accuracy: 0.9925 - val_loss: 0.6368 - val_accuracy: 0.8396
# Epoch 56/70
# 39/39 [==============================] - 59s 2s/step - loss: 0.0178 - accuracy: 0.9961 - val_loss: 0.6803 - val_accuracy: 0.8304
# Epoch 57/70
# 39/39 [==============================] - 58s 1s/step - loss: 0.0243 - accuracy: 0.9935 - val_loss: 0.7145 - val_accuracy: 0.8250
# Epoch 58/70
# 39/39 [==============================] - 54s 1s/step - loss: 0.0408 - accuracy: 0.9870 - val_loss: 0.7383 - val_accuracy: 0.8227
# Epoch 59/70
# 39/39 [==============================] - 58s 1s/step - loss: 0.0273 - accuracy: 0.9929 - val_loss: 0.6984 - val_accuracy: 0.8327
# Epoch 60/70
# 39/39 [==============================] - 58s 1s/step - loss: 0.0168 - accuracy: 0.9966 - val_loss: 0.6840 - val_accuracy: 0.8412
# Epoch 61/70
# 39/39 [==============================] - 62s 2s/step - loss: 0.0140 - accuracy: 0.9973 - val_loss: 0.6051 - val_accuracy: 0.8512
# Epoch 62/70
# 39/39 [==============================] - 60s 2s/step - loss: 0.0277 - accuracy: 0.9912 - val_loss: 0.9446 - val_accuracy: 0.7841
# Epoch 63/70
# 39/39 [==============================] - 60s 2s/step - loss: 0.0210 - accuracy: 0.9941 - val_loss: 0.6514 - val_accuracy: 0.8512
# Epoch 64/70
# 39/39 [==============================] - 62s 2s/step - loss: 0.0148 - accuracy: 0.9962 - val_loss: 0.7014 - val_accuracy: 0.8404
# Epoch 65/70
# 39/39 [==============================] - 62s 2s/step - loss: 0.0106 - accuracy: 0.9980 - val_loss: 0.6606 - val_accuracy: 0.8473
# Epoch 66/70
# 39/39 [==============================] - 64s 2s/step - loss: 0.0112 - accuracy: 0.9979 - val_loss: 0.6823 - val_accuracy: 0.8481
# Epoch 67/70
# 39/39 [==============================] - 60s 2s/step - loss: 0.0156 - accuracy: 0.9957 - val_loss: 0.8534 - val_accuracy: 0.8096
# Epoch 68/70
# 39/39 [==============================] - 68s 2s/step - loss: 0.0158 - accuracy: 0.9958 - val_loss: 0.9751 - val_accuracy: 0.7903
# Epoch 69/70
# 39/39 [==============================] - 69s 2s/step - loss: 0.0181 - accuracy: 0.9954 - val_loss: 0.7257 - val_accuracy: 0.8427
# Epoch 70/70
# 39/39 [==============================] - 62s 2s/step - loss: 0.0122 - accuracy: 0.9971 - val_loss: 0.6466 - val_accuracy: 0.8512

# %%
def inv_Transform_result(y_pred):    
    y_pred = y_pred.argmax(axis=1)
    y_pred = encoder.inverse_transform(y_pred)
    return y_pred



y_pred=cnn_model.predict(X_test)

score = cnn_model.evaluate(X_test, y_test, verbose = 0) 

print('Test loss:', score[0]) 
print('Test accuracy:', score[1])

Y_pred=inv_Transform_result(y_pred)
Y_test = inv_Transform_result(y_test)




from sklearn.metrics import confusion_matrix


plt.figure(figsize=(10,10))
cm = confusion_matrix(Y_test, Y_pred,normalize='true')
f = sns.heatmap(cm, annot=True,xticklabels=encoder.classes_,yticklabels=encoder.classes_)
plt.show()
# Out:
# Test loss: 0.6503528952598572
# Test accuracy: 0.849429190158844

# %%
from keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall 

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

recall = recall_m(y_test,y_pred)

print("Recall: ",recall)
print("Precision: ",precision_m(y_test,y_pred))
print("F1 Score: " ,f1_m(y_test,y_pred))
# Out:
# Recall:  tf.Tensor(0.8463437, shape=(), dtype=float32)
# Precision:  tf.Tensor(0.85345364, shape=(), dtype=float32)
# F1 Score:  tf.Tensor(0.84988374, shape=(), dtype=float32)

# %%
dummy_cnn = Model(inputs=cnn_model.input,outputs=cnn_model.layers[8].output)
y_viz = dummy_cnn.predict(X_train)

# %%
from sklearn.manifold import TSNE

X_t_sne = TSNE(n_components=2, learning_rate='auto',verbose=1, perplexity=40, n_iter=300).fit_transform(y_viz)

tSNEdf = pd.DataFrame(data = X_t_sne, columns = ['T-SNE component 1', 'T-SNE component 2'])

tSNEdf['Fault']=inv_Transform_result(y_train)


# Plot the PC-1 and PC-2
fig, ax = plt.subplots(figsize=(10,10))
sns.scatterplot(x=tSNEdf['T-SNE component 1'],y=tSNEdf['T-SNE component 2'],hue='Fault',
    data=tSNEdf,
    legend="full",
    alpha=0.3)
plt.show()
# Out:
# /Users/divyanshuchaudhari/miniforge3/envs/pytorch_m1/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 12964 samples in 0.001s...
# [t-SNE] Computed neighbors for 12964 samples in 4.833s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 12964
# [t-SNE] Computed conditional probabilities for sample 2000 / 12964
# [t-SNE] Computed conditional probabilities for sample 3000 / 12964
# [t-SNE] Computed conditional probabilities for sample 4000 / 12964
# [t-SNE] Computed conditional probabilities for sample 5000 / 12964
# [t-SNE] Computed conditional probabilities for sample 6000 / 12964
# [t-SNE] Computed conditional probabilities for sample 7000 / 12964
# [t-SNE] Computed conditional probabilities for sample 8000 / 12964
# [t-SNE] Computed conditional probabilities for sample 9000 / 12964
# [t-SNE] Computed conditional probabilities for sample 10000 / 12964
# [t-SNE] Computed conditional probabilities for sample 11000 / 12964
# [t-SNE] Computed conditional probabilities for sample 12000 / 12964
# [t-SNE] Computed conditional probabilities for sample 12964 / 12964
# [t-SNE] Mean sigma: 0.923034
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 71.098236
# [t-SNE] KL divergence after 300 iterations: 2.576473
